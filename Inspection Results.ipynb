# %%
pip install bokeh
# Out:
# Requirement already satisfied: bokeh in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bokeh) (5.4.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bokeh) (2.8.1)
# Requirement already satisfied: Jinja2>=2.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bokeh) (2.11.3)
# Requirement already satisfied: numpy>=1.11.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bokeh) (1.20.1)
# Requirement already satisfied: pillow>=7.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bokeh) (8.1.2)
# Requirement already satisfied: packaging>=16.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bokeh) (20.9)
# Requirement already satisfied: tornado>=5.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bokeh) (6.1)
# Requirement already satisfied: typing_extensions>=3.7.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bokeh) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.1->bokeh) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from Jinja2>=2.7->bokeh) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from packaging>=16.8->bokeh) (2.4.7)
# You are using pip version 19.0.3, however version 21.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from bokeh.io import push_notebook, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('Inspection Results.csv')
df
# Out:
#            CAMIS                              DBA       BORO BUILDING  \
# 0       50010490                          WENDY'S  Manhattan       85
# 1       41035487                PADDY DUGGANS PUB     Queens     4714
# 2       41421128                         MARY O'S  Manhattan       32
# 3       50059605                THE KING OF TACOS     Queens     9017
# 4       41697391  STAR KABAB & CHINESE RESTAURANT     Queens    16821
# ...          ...                              ...        ...      ...
# 419511  41612649                MISH MASH GOURMET   Brooklyn     1103
# 419512  41612649                MISH MASH GOURMET   Brooklyn     1103
# 419513  50070389                    MANI IN PASTA  Manhattan      245
# 419514  50048635                LE PAIN QUOTIDIEN  Manhattan     2098
# 419515  41568640           HOT POT UNDER DE' TREE  Manhattan     2839
#
#                              STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0                     NASSAU STREET  10038.0  2126193322            American
# 1                 GREENPOINT AVENUE  11104.0  7184157399   Bottled Beverages
# 2                          AVENUE A  10009.0  2125055610            American
# 3                          31ST AVE  11369.0  7184240299             Tex-Mex
# 4                   HILLSIDE AVENUE  11432.0  7185260400         Bangladeshi
# ...                             ...      ...         ...                 ...
# 419511                KINGS HIGHWAY  11229.0  7183755100            American
# 419512                KINGS HIGHWAY  11229.0  7183755100            American
# 419513             EAST   14 STREET  10003.0  6468910174               Pizza
# 419514                     BROADWAY  10023.0  2127129700          Coffee/Tea
# 419515  FREDERICK DOUGLAS BOULEVARD  10039.0  2122343505           Caribbean
#
#        INSPECTION DATE ACTION  ... RECORD DATE  \
# 0           07/13/2018      D  ...  05/13/2021
# 1           03/22/2018      P  ...  05/13/2021
# 2           02/13/2018      D  ...  05/13/2021
# 3           02/29/2020      U  ...  05/13/2021
# 4           04/19/2018      F  ...  05/13/2021
# ...                ...    ...  ...         ...
# 419511      02/13/2017      D  ...  05/13/2021
# 419512      02/13/2017      D  ...  05/13/2021
# 419513      06/07/2019      U  ...  05/13/2021
# 419514      01/12/2018      D  ...  05/13/2021
# 419515      04/06/2018      P  ...  05/13/2021
#
#                               INSPECTION TYPE   Latitude  Longitude  \
# 0            Cycle Inspection / Re-inspection  40.709969 -74.007997
# 1       Cycle Inspection / Initial Inspection  40.742564 -73.917623
# 2       Cycle Inspection / Initial Inspection  40.723330 -73.985501
# 3            Cycle Inspection / Re-inspection  40.760041 -73.878349
# 4            Cycle Inspection / Re-inspection  40.710246 -73.794158
# ...                                       ...        ...        ...
# 419511  Cycle Inspection / Initial Inspection  40.607396 -73.961731
# 419512  Cycle Inspection / Initial Inspection  40.607396 -73.961731
# 419513  Cycle Inspection / Initial Inspection  40.732854 -73.986137
# 419514  Cycle Inspection / Initial Inspection  40.779183 -73.981943
# 419515  Cycle Inspection / Initial Inspection  40.826841 -73.938996
#
#        Community Board Council District Census Tract        BIN           BBL  \
# 0                101.0              1.0       1502.0  1001212.0  1.000790e+09
# 1                402.0             26.0      23500.0  4001545.0  4.001510e+09
# 2                103.0              2.0       3002.0  1004963.0  1.003980e+09
# 3                403.0             22.0      35100.0  4445870.0  4.013880e+09
# 4                408.0             24.0      45400.0  4210524.0  4.098400e+09
# ...                ...              ...          ...        ...           ...
# 419511           315.0             48.0      55400.0  3182818.0  3.067940e+09
# 419512           315.0             48.0      55400.0  3182818.0  3.067940e+09
# 419513           106.0              2.0       4800.0  1019514.0  1.008960e+09
# 419514           107.0              6.0      15900.0  1000000.0  1.011640e+09
# 419515           110.0              9.0      23502.0  1060862.0  1.020460e+09
#
#          NTA
# 0       MN25
# 1       QN31
# 2       MN22
# 3       QN28
# 4       QN35
# ...      ...
# 419511  BK25
# 419512  BK25
# 419513  MN21
# 419514  MN14
# 419515  MN03
#
# [419516 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 419516 entries, 0 to 419515
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  419516 non-null  int64
#  1   DBA                    418686 non-null  object
#  2   BORO                   419516 non-null  object
#  3   BUILDING               418554 non-null  object
#  4   STREET                 419425 non-null  object
#  5   ZIPCODE                412573 non-null  float64
#  6   PHONE                  419478 non-null  object
#  7   CUISINE DESCRIPTION    415502 non-null  object
#  8   INSPECTION DATE        419516 non-null  object
#  9   ACTION                 415502 non-null  object
#  10  VIOLATION CODE         410136 non-null  object
#  11  VIOLATION DESCRIPTION  412938 non-null  object
#  12  CRITICAL FLAG          412939 non-null  object
#  13  SCORE                  400058 non-null  float64
#  14  GRADE                  214691 non-null  object
#  15  GRADE DATE             212234 non-null  object
#  16  RECORD DATE            419516 non-null  object
#  17  INSPECTION TYPE        415502 non-null  object
#  18  Latitude               418923 non-null  float64
#  19  Longitude              418923 non-null  float64
#  20  Community Board        411343 non-null  float64
#  21  Council District       411343 non-null  float64
#  22  Census Tract           411343 non-null  float64
#  23  BIN                    409427 non-null  float64
#  24  BBL                    418157 non-null  float64
#  25  NTA                    411343 non-null  object
# dtypes: float64(9), int64(1), object(16)
# memory usage: 83.2+ MB

# %%
df = df.groupby(['DBA','CUISINE DESCRIPTION'])['ACTION'].count()

# %%
df
# Out:
# DBA                                   CUISINE DESCRIPTION
# #1 Chinese Restaurant                 Chinese                           26
# #1 GARDEN CHINESE RESTAURANT          Chinese                           29
# #1 NATURAL JUICE BAR                  Juice, Smoothies, Fruit Salads    19
# #1 SABOR LATINO RESTAURANT            Latin American                    21
# $1 PIZZA                              Pizza                             15
#                                                                         ..
# iPizzaNY                              Pizza                             21
# inthemix jamaican & southern cuisine  Caribbean                          7
# matchpointnyc                         Soups/Salads/Sandwiches           18
# tutto il giorno                       Italian                           11
# wok and roll kitchen                  Other                              2
# Name: ACTION, Length: 20918, dtype: int64

# %%
import pandas as pd

from bokeh.layouts import column, row
from bokeh.models import Select
from bokeh.palettes import Spectral5
from bokeh.plotting import curdoc, figure
from bokeh.sampledata.autompg import autompg_clean as df

df = pd.read_csv('Inspection Results.csv')

SIZES = list(range(6, 22, 3))
COLORS = Spectral5
N_SIZES = len(SIZES)
N_COLORS = len(COLORS)

# data cleanup
df.cyl = df.cyl.astype(str)
df.yr = df.yr.astype(str)
del df['Inspection Results']

columns = sorted(df.columns)
discrete = [x for x in columns if df[x].dtype == object]
continuous = [x for x in columns if x not in discrete]

def create_figure():
    xs = df[x.value].values
    ys = df[y.value].values
    x_title = x.value.title()
    y_title = y.value.title()

    kw = dict()
    if x.value in discrete:
        kw['x_range'] = sorted(set(xs))
    if y.value in discrete:
        kw['y_range'] = sorted(set(ys))
    kw['title'] = "%s vs %s" % (x_title, y_title)

    p = figure(height=600, width=800, tools='pan,box_zoom,hover,reset', **kw)
    p.xaxis.axis_label = x_title
    p.yaxis.axis_label = y_title

    if x.value in discrete:
        p.xaxis.major_label_orientation = pd.np.pi / 4

    sz = 9
    if size.value != 'None':
        if len(set(df[size.value])) > N_SIZES:
            groups = pd.qcut(df[size.value].values, N_SIZES, duplicates='drop')
        else:
            groups = pd.Categorical(df[size.value])
        sz = [SIZES[xx] for xx in groups.codes]

    c = "#31AADE"
    if color.value != 'None':
        if len(set(df[color.value])) > N_COLORS:
            groups = pd.qcut(df[color.value].values, N_COLORS, duplicates='drop')
        else:
            groups = pd.Categorical(df[color.value])
        c = [COLORS[xx] for xx in groups.codes]

    p.circle(x=xs, y=ys, color=c, size=sz, line_color="white", alpha=0.6, hover_color='white', hover_alpha=0.5)

    return p


def update(attr, old, new):
    layout.children[1] = create_figure()


x = Select(title='X-Axis', value='mpg', options=columns)
x.on_change('value', update)

y = Select(title='Y-Axis', value='hp', options=columns)
y.on_change('value', update)

size = Select(title='Size', value='None', options=['None'] + continuous)
size.on_change('value', update)

color = Select(title='Color', value='None', options=['None'] + continuous)
color.on_change('value', update)

controls = column(x, y, color, size, width=200)
layout = row(controls, create_figure())

curdoc().add_root(layout)
curdoc().title = "Crossfilter"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-be98c6532b6a> in <module>
#      15
#      16 # data cleanup
# ---> 17 df.cyl = df.cyl.astype(str)
#      18 df.yr = df.yr.astype(str)
#      19 del df['Inspection Results']
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'cyl'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d677e7740d74> in <module>
# ----> 1 p
#
# NameError: name 'p' is not defined

# %%
bokeh serve --show crossfilter
